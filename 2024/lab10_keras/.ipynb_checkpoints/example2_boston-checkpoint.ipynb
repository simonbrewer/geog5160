# %% [markdown]
# ## Example 2: regression
#
# For the second example, we'll demonstrate a regression example, as well as a $k$-fold cross-validation. We'll use data on house prices and neighborhood characteristics from Boston, in the file *boston6k.csv*. Start by reading this data in, and take a quick look at the values:

# %%
import numpy as np
import pandas as pd

boston = pd.read_csv("../datafiles/boston6k.csv")

# %% [markdown]
# Load data

# %%
boston.head()
# Out:
#    ID                     TOWN  TOWNNO  TRACT        LON        LAT  MEDV  \
# 0   1  Boston Allston-Brighton      74      1 -71.139367  42.362447  17.8
# 1   2  Boston Allston-Brighton      74      2 -71.158552  42.353116  21.7
# 2   3  Boston Allston-Brighton      74      3 -71.168487  42.350608  22.7
# 3   4  Boston Allston-Brighton      74      4 -71.156163  42.343818  22.6
# 4   5  Boston Allston-Brighton      74      5 -71.155807  42.337318  25.0
#
#    CMEDV     CRIM   ZN  ...  CHAS   NOX     RM   AGE     DIS  RAD  TAX  \
# 0   17.8  8.98296  0.0  ...     1  0.77  6.212  97.4  2.1222   24  666
# 1   21.7  3.84970  0.0  ...     1  0.77  6.395  91.0  2.5052   24  666
# 2   22.7  5.20177  0.0  ...     1  0.77  6.127  83.4  2.7227   24  666
# 3   22.6  4.26131  0.0  ...     0  0.77  6.112  81.3  2.5091   24  666
# 4   25.0  4.54192  0.0  ...     0  0.77  6.398  88.0  2.5182   24  666
#
#    PTRATIO       B  LSTAT
# 0     20.2  377.73  17.60
# 1     20.2  391.34  13.27
# 2     20.2  395.43  11.48
# 3     20.2  390.74  12.67
# 4     20.2  374.56   7.79
#
# [5 rows x 21 columns]

# %% [markdown]
# Summary information

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 21 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ID       506 non-null    int64
#  1   TOWN     506 non-null    object
#  2   TOWNNO   506 non-null    int64
#  3   TRACT    506 non-null    int64
#  4   LON      506 non-null    float64
#  5   LAT      506 non-null    float64
#  6   MEDV     506 non-null    float64
#  7   CMEDV    506 non-null    float64
#  8   CRIM     506 non-null    float64
#  9   ZN       506 non-null    float64
#  10  INDUS    506 non-null    float64
#  11  CHAS     506 non-null    int64
#  12  NOX      506 non-null    float64
#  13  RM       506 non-null    float64
#  14  AGE      506 non-null    float64
#  15  DIS      506 non-null    float64
#  16  RAD      506 non-null    int64
#  17  TAX      506 non-null    int64
#  18  PTRATIO  506 non-null    float64
#  19  B        506 non-null    float64
#  20  LSTAT    506 non-null    float64
# dtypes: float64(14), int64(6), object(1)
# memory usage: 83.1+ KB

# %% [markdown]
# Value

# %%
boston.describe()
# Out:
#                ID      TOWNNO        TRACT         LON         LAT  \
# count  506.000000  506.000000   506.000000  506.000000  506.000000
# mean   253.500000   47.531621  2700.355731  -71.094343   42.360270
# std    146.213884   27.571401  1380.036830    0.125508    0.103696
# min      1.000000    0.000000     1.000000  -71.485152   42.045973
# 25%    127.250000   26.250000  1303.250000  -71.156074   42.299922
# 50%    253.500000   42.000000  3393.500000  -71.088686   42.362347
# 75%    379.750000   78.000000  3739.750000  -71.031016   42.423070
# max    506.000000   91.000000  5082.000000  -70.680481   42.637086
#
#              MEDV       CMEDV        CRIM          ZN       INDUS        CHAS  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    22.532806   22.528854    3.613524   11.363636   11.136779    0.069170
# std      9.197104    9.182176    8.601545   23.322453    6.860353    0.253994
# min      5.000000    5.000000    0.006320    0.000000    0.460000    0.000000
# 25%     17.025000   17.025000    0.082045    0.000000    5.190000    0.000000
# 50%     21.200000   21.200000    0.256510    0.000000    9.690000    0.000000
# 75%     25.000000   25.000000    3.677083   12.500000   18.100000    0.000000
# max     50.000000   50.000000   88.976200  100.000000   27.740000    1.000000
#
#               NOX          RM         AGE         DIS         RAD         TAX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     0.554695    6.284634   68.574901    3.795043    9.549407  408.237154
# std      0.115878    0.702617   28.148861    2.105710    8.707259  168.537116
# min      0.385000    3.561000    2.900000    1.129600    1.000000  187.000000
# 25%      0.449000    5.885500   45.025000    2.100175    4.000000  279.000000
# 50%      0.538000    6.208500   77.500000    3.207450    5.000000  330.000000
# 75%      0.624000    6.623500   94.075000    5.188425   24.000000  666.000000
# max      0.871000    8.780000  100.000000   12.126500   24.000000  711.000000
#
#           PTRATIO           B       LSTAT
# count  506.000000  506.000000  506.000000
# mean    18.455534  356.674032   12.653063
# std      2.164946   91.294864    7.141062
# min     12.600000    0.320000    1.730000
# 25%     17.400000  375.377500    6.950000
# 50%     19.050000  391.440000   11.360000
# 75%     20.200000  396.225000   16.955000
# max     22.000000  396.900000   37.970000

# %% [markdown]
# Matplotlib example - note the inline statement for jupyter

# %%
boston2 = boston.iloc[:,7:21]
boston2.columns
# Out:
# Index(['CMEDV', 'CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS',
#        'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'],
#       dtype='object')

# %%
## %matplotlib inline
import matplotlib.pyplot as plt
boston2.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# Uses scikit to split data into training and test

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(boston2, test_size=0.2, random_state=42)

# %% [markdown]
# Split into features and labels

# %%
X_train = train.drop('CMEDV', axis=1).values
y_train = train['CMEDV'].values
print(X_train.shape)
print(y_train.shape)
# Out:
# (404, 13)
# (404,)

# %%
X_test = test.drop('CMEDV', axis=1).values
y_test = test['CMEDV'].values
print(X_test.shape)
print(y_test.shape)
# Out:
# (102, 13)
# (102,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
print(scaler.mean_)
print(np.sqrt(scaler.scale_))
# Out:
# [3.64850188e+00 1.12995050e+01 1.11347277e+01 7.42574257e-02
#  5.54586139e-01 6.28753218e+00 6.85789604e+01 3.78350668e+00
#  9.31188119e+00 4.05059406e+02 1.84210396e+01 3.61775916e+02
#  1.25574010e+01]
# [ 3.03163637  4.85881638  2.60725352  0.51204429  0.3427726   0.82121576
#   5.3430648   1.43893625  2.93117272 12.89879379  1.4683956   9.10935061
#   2.68610613]

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential([
  layers.Dense(64, activation='relu', input_shape=(13,)),
  layers.Dense(64, activation='relu'),
  layers.Dense(1, activation='sigmoid')
])

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes = True)

# %% [markdown]
# Create a function to build the network architecture. This will allows us to recycle this in a cross-validation exercise.

# %%
def build_model():
    model = models.Sequential([                        

      layers.Dense(64, activation='relu', input_shape=(13,)),
      layers.Dense(64, activation='relu'),
      layers.Dense(1)
    ])
    model.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])
    return model

# %%
model = build_model()
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes = True)

# %% [markdown]
# $k$-fold

# %%
## scikit learn method
k = 4
from sklearn.model_selection import KFold
kf = KFold(n_splits = k)

num_epochs = 250
all_mae_histories = []
i = 1
for train_partial_index, val_index in kf.split(X_train):
    print('processing fold #%d' % i)
    X_val = X_train[val_index]  
    y_val = y_train[val_index]
    
    X_partial_train = X_train[train_partial_index]
    y_partial_train = y_train[train_partial_index]
    
    model = build_model()                                                  

    history = model.fit(X_partial_train, y_partial_train,
                        validation_data=(X_val, y_val),
                        epochs=num_epochs, batch_size=16, verbose=0)
    
    mae_history = history.history['val_mae']
    all_mae_histories.append(mae_history)
    i += 1
# Out:
# processing fold #1
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x150f59700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x150f59700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2023-04-16 16:21:39.729444: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2023-04-16 16:21:39.729604: W tensorflow/core/platform/profile_utils/cpu_utils.cc:126] Failed to get CPU frequency: 0 Hz
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1546b7ee0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1546b7ee0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# processing fold #2
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154710700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154710700> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x154710820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x154710820> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# processing fold #3
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154779280> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x154779280> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x14f708160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x14f708160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# processing fold #4
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x150f5de50> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x150f5de50> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x150f590d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x150f590d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
k = 4
num_val_samples = len(X_train) // k

num_epochs = 250
all_mae_histories = []
for i in range(k):
    print('processing fold #%d' % i)
    X_val = X_train[i * num_val_samples: (i + 1) * num_val_samples]  

    y_val = y_train[i * num_val_samples: (i + 1) * num_val_samples]
    
    X_partial_train = np.concatenate(                                   
        [X_train[:i * num_val_samples],
         X_train[(i + 1) * num_val_samples:]],
        axis=0)
    
    y_partial_train = np.concatenate(
        [y_train[:i * num_val_samples],
         y_train[(i + 1) * num_val_samples:]],
        axis=0)
    
    model = build_model()                                                  

    history = model.fit(X_partial_train, y_partial_train,
                        validation_data=(X_val, y_val),
                        epochs=num_epochs, batch_size=16, verbose=0)
    
    mae_history = history.history['val_mae']
    all_mae_histories.append(mae_history)
# Out:
# processing fold #0
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1546f1790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x1546f1790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x155233d30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x155233d30> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# processing fold #1
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x155a31940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x155a31940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x155a3c4c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x155a3c4c0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# processing fold #2
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15616c160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x15616c160> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1561da0d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1561da0d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# processing fold #3
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x157187940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x157187940> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1571e5c10> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x1571e5c10> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert

# %%
average_mae_history = [
    np.mean([x[i] for x in all_mae_histories]) for i in range(num_epochs)]

# %%
plt.plot(range(1, len(average_mae_history) + 1), average_mae_history)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE')
plt.show()

# %%
average_mae_history2 = average_mae_history[10:]
plt.plot(range(1, len(average_mae_history2) + 1), average_mae_history2)
plt.xlabel('Epochs')
plt.ylabel('Validation MAE')
plt.show()

# %%
model = build_model()
history = model.fit(X_train, y_train,
                        validation_data=(X_test, y_test),
                        epochs=125, batch_size=16, verbose=1)
# Out:
# Epoch 1/125
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x157dba670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x157dba670> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
#  1/26 [>.............................] - ETA: 3s - loss: 536.6516 - mae: 21.5165WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x157de2a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x157de2a60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: unsupported operand type(s) for -: 'NoneType' and 'int'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 26/26 [==============================] - 0s 3ms/step - loss: 550.8472 - mae: 21.5611 - val_loss: 427.0425 - val_mae: 18.3880
# Epoch 2/125
# 26/26 [==============================] - 0s 974us/step - loss: 358.1181 - mae: 17.0640 - val_loss: 226.0405 - val_mae: 12.4919
# Epoch 3/125
# 26/26 [==============================] - 0s 971us/step - loss: 209.5695 - mae: 12.3634 - val_loss: 100.3340 - val_mae: 7.4953
# Epoch 4/125
# 26/26 [==============================] - 0s 937us/step - loss: 75.4458 - mae: 7.0120 - val_loss: 47.4633 - val_mae: 5.0691
# Epoch 5/125
# 26/26 [==============================] - 0s 930us/step - loss: 43.2578 - mae: 4.8559 - val_loss: 25.3125 - val_mae: 3.6972
# Epoch 6/125
# 26/26 [==============================] - 0s 998us/step - loss: 38.8081 - mae: 4.2914 - val_loss: 21.2785 - val_mae: 3.3293
# Epoch 7/125
# 26/26 [==============================] - 0s 984us/step - loss: 29.1192 - mae: 3.8990 - val_loss: 18.9136 - val_mae: 3.1865
# Epoch 8/125
# 26/26 [==============================] - 0s 926us/step - loss: 25.8317 - mae: 3.7615 - val_loss: 15.3385 - val_mae: 2.8592
# Epoch 9/125
# 26/26 [==============================] - 0s 909us/step - loss: 19.4290 - mae: 3.1454 - val_loss: 13.5039 - val_mae: 2.6873
# Epoch 10/125
# 26/26 [==============================] - 0s 937us/step - loss: 17.2285 - mae: 2.9887 - val_loss: 12.5392 - val_mae: 2.6870
# Epoch 11/125
# 26/26 [==============================] - 0s 899us/step - loss: 19.9046 - mae: 3.1629 - val_loss: 13.2772 - val_mae: 2.6720
# Epoch 12/125
# 26/26 [==============================] - 0s 911us/step - loss: 15.6688 - mae: 2.7714 - val_loss: 12.5854 - val_mae: 2.5039
# Epoch 13/125
# 26/26 [==============================] - 0s 895us/step - loss: 20.1772 - mae: 2.8976 - val_loss: 10.7817 - val_mae: 2.3849
# Epoch 14/125
# 26/26 [==============================] - 0s 896us/step - loss: 18.4158 - mae: 2.8206 - val_loss: 10.7524 - val_mae: 2.3864
# Epoch 15/125
# 26/26 [==============================] - 0s 884us/step - loss: 15.3680 - mae: 2.7170 - val_loss: 11.4710 - val_mae: 2.4204
# Epoch 16/125
# 26/26 [==============================] - 0s 893us/step - loss: 15.7172 - mae: 2.6589 - val_loss: 10.3991 - val_mae: 2.5867
# Epoch 17/125
# 26/26 [==============================] - 0s 899us/step - loss: 13.7228 - mae: 2.5889 - val_loss: 10.2457 - val_mae: 2.3270
# Epoch 18/125
# 26/26 [==============================] - 0s 899us/step - loss: 11.5917 - mae: 2.4156 - val_loss: 9.7098 - val_mae: 2.3458
# Epoch 19/125
# 26/26 [==============================] - 0s 901us/step - loss: 11.5309 - mae: 2.4025 - val_loss: 10.3627 - val_mae: 2.5037
# Epoch 20/125
# 26/26 [==============================] - 0s 901us/step - loss: 14.2002 - mae: 2.6847 - val_loss: 10.0750 - val_mae: 2.4572
# Epoch 21/125
# 26/26 [==============================] - 0s 890us/step - loss: 14.6270 - mae: 2.4376 - val_loss: 9.5591 - val_mae: 2.3599
# Epoch 22/125
# 26/26 [==============================] - 0s 899us/step - loss: 14.4023 - mae: 2.5360 - val_loss: 9.2255 - val_mae: 2.3294
# Epoch 23/125
# 26/26 [==============================] - 0s 871us/step - loss: 16.0952 - mae: 2.5987 - val_loss: 10.1630 - val_mae: 2.3889
# Epoch 24/125
# 26/26 [==============================] - 0s 900us/step - loss: 10.8992 - mae: 2.2605 - val_loss: 9.5838 - val_mae: 2.3388
# Epoch 25/125
# 26/26 [==============================] - 0s 891us/step - loss: 10.8884 - mae: 2.2852 - val_loss: 10.2443 - val_mae: 2.4175
# Epoch 26/125
# 26/26 [==============================] - 0s 879us/step - loss: 11.6582 - mae: 2.3355 - val_loss: 9.6810 - val_mae: 2.4386
# Epoch 27/125
# 26/26 [==============================] - 0s 887us/step - loss: 10.6296 - mae: 2.3501 - val_loss: 10.1155 - val_mae: 2.3345
# Epoch 28/125
# 26/26 [==============================] - 0s 892us/step - loss: 8.2532 - mae: 2.1085 - val_loss: 10.1942 - val_mae: 2.4353
# Epoch 29/125
# 26/26 [==============================] - 0s 879us/step - loss: 10.6660 - mae: 2.3011 - val_loss: 11.4622 - val_mae: 2.5912
# Epoch 30/125
# 26/26 [==============================] - 0s 933us/step - loss: 14.3021 - mae: 2.4751 - val_loss: 10.1361 - val_mae: 2.4304
# Epoch 31/125
# 26/26 [==============================] - 0s 926us/step - loss: 10.8294 - mae: 2.2313 - val_loss: 9.5321 - val_mae: 2.3946
# Epoch 32/125
# 26/26 [==============================] - 0s 924us/step - loss: 12.0367 - mae: 2.2660 - val_loss: 10.3860 - val_mae: 2.4664
# Epoch 33/125
# 26/26 [==============================] - 0s 936us/step - loss: 12.1852 - mae: 2.3273 - val_loss: 11.6622 - val_mae: 2.5756
# Epoch 34/125
# 26/26 [==============================] - 0s 944us/step - loss: 12.7614 - mae: 2.4388 - val_loss: 10.1750 - val_mae: 2.4291
# Epoch 35/125
# 26/26 [==============================] - 0s 938us/step - loss: 10.0159 - mae: 2.2458 - val_loss: 11.0594 - val_mae: 2.5432
# Epoch 36/125
# 26/26 [==============================] - 0s 946us/step - loss: 9.2170 - mae: 2.0808 - val_loss: 9.1197 - val_mae: 2.3252
# Epoch 37/125
# 26/26 [==============================] - 0s 934us/step - loss: 8.9327 - mae: 2.1664 - val_loss: 9.1974 - val_mae: 2.2782
# Epoch 38/125
# 26/26 [==============================] - 0s 934us/step - loss: 10.3647 - mae: 2.1694 - val_loss: 10.1569 - val_mae: 2.4315
# Epoch 39/125
# 26/26 [==============================] - 0s 941us/step - loss: 9.9859 - mae: 2.1974 - val_loss: 10.7804 - val_mae: 2.5054
# Epoch 40/125
# 26/26 [==============================] - 0s 958us/step - loss: 8.3525 - mae: 2.0396 - val_loss: 9.6661 - val_mae: 2.3422
# Epoch 41/125
# 26/26 [==============================] - 0s 935us/step - loss: 9.3228 - mae: 2.1482 - val_loss: 10.5534 - val_mae: 2.4627
# Epoch 42/125
# 26/26 [==============================] - 0s 936us/step - loss: 8.4655 - mae: 2.0720 - val_loss: 9.8312 - val_mae: 2.3931
# Epoch 43/125
# 26/26 [==============================] - 0s 944us/step - loss: 8.9040 - mae: 2.0761 - val_loss: 10.1523 - val_mae: 2.4122
# Epoch 44/125
# 26/26 [==============================] - 0s 971us/step - loss: 7.1450 - mae: 1.9405 - val_loss: 9.7939 - val_mae: 2.3906
# Epoch 45/125
# 26/26 [==============================] - 0s 976us/step - loss: 7.7378 - mae: 1.9622 - val_loss: 10.5663 - val_mae: 2.4898
# Epoch 46/125
# 26/26 [==============================] - 0s 1ms/step - loss: 7.8689 - mae: 1.9710 - val_loss: 10.8278 - val_mae: 2.5051
# Epoch 47/125
# 26/26 [==============================] - 0s 992us/step - loss: 7.1707 - mae: 1.9464 - val_loss: 8.9557 - val_mae: 2.2628
# Epoch 48/125
# 26/26 [==============================] - 0s 977us/step - loss: 7.1037 - mae: 2.0015 - val_loss: 10.1598 - val_mae: 2.3958
# Epoch 49/125
# 26/26 [==============================] - 0s 976us/step - loss: 8.1907 - mae: 2.0361 - val_loss: 11.3452 - val_mae: 2.5021
# Epoch 50/125
# 26/26 [==============================] - 0s 951us/step - loss: 7.5931 - mae: 2.0332 - val_loss: 9.7217 - val_mae: 2.3728
# Epoch 51/125
# 26/26 [==============================] - 0s 957us/step - loss: 7.1198 - mae: 1.8956 - val_loss: 10.8039 - val_mae: 2.5258
# Epoch 52/125
# 26/26 [==============================] - 0s 962us/step - loss: 7.1848 - mae: 1.9939 - val_loss: 11.0194 - val_mae: 2.4967
# Epoch 53/125
# 26/26 [==============================] - 0s 938us/step - loss: 9.6165 - mae: 2.0138 - val_loss: 8.8488 - val_mae: 2.2496
# Epoch 54/125
# 26/26 [==============================] - 0s 937us/step - loss: 7.6260 - mae: 1.9146 - val_loss: 9.1904 - val_mae: 2.2887
# Epoch 55/125
# 26/26 [==============================] - 0s 885us/step - loss: 10.1227 - mae: 2.0514 - val_loss: 11.6962 - val_mae: 2.6413
# Epoch 56/125
# 26/26 [==============================] - 0s 927us/step - loss: 9.9157 - mae: 2.0346 - val_loss: 9.7979 - val_mae: 2.3283
# Epoch 57/125
# 26/26 [==============================] - 0s 958us/step - loss: 7.6173 - mae: 1.9623 - val_loss: 9.2875 - val_mae: 2.3396
# Epoch 58/125
# 26/26 [==============================] - 0s 971us/step - loss: 6.4002 - mae: 1.7847 - val_loss: 12.2386 - val_mae: 2.5772
# Epoch 59/125
# 26/26 [==============================] - 0s 933us/step - loss: 6.4343 - mae: 1.8841 - val_loss: 9.2458 - val_mae: 2.2871
# Epoch 60/125
# 26/26 [==============================] - 0s 935us/step - loss: 7.6311 - mae: 1.8843 - val_loss: 10.9634 - val_mae: 2.4673
# Epoch 61/125
# 26/26 [==============================] - 0s 969us/step - loss: 6.8266 - mae: 1.8874 - val_loss: 11.9885 - val_mae: 2.5934
# Epoch 62/125
# 26/26 [==============================] - 0s 984us/step - loss: 6.6547 - mae: 1.8870 - val_loss: 11.5594 - val_mae: 2.5179
# Epoch 63/125
# 26/26 [==============================] - 0s 1ms/step - loss: 7.0487 - mae: 1.9377 - val_loss: 9.7445 - val_mae: 2.2993
# Epoch 64/125
# 26/26 [==============================] - 0s 969us/step - loss: 6.0452 - mae: 1.8616 - val_loss: 11.0913 - val_mae: 2.4652
# Epoch 65/125
# 26/26 [==============================] - 0s 950us/step - loss: 6.8118 - mae: 1.8308 - val_loss: 11.6716 - val_mae: 2.5609
# Epoch 66/125
# 26/26 [==============================] - 0s 968us/step - loss: 7.8073 - mae: 1.9516 - val_loss: 9.3407 - val_mae: 2.2680
# Epoch 67/125
# 26/26 [==============================] - 0s 913us/step - loss: 7.2831 - mae: 1.8061 - val_loss: 9.6114 - val_mae: 2.2695
# Epoch 68/125
# 26/26 [==============================] - 0s 910us/step - loss: 6.3588 - mae: 1.8542 - val_loss: 9.1201 - val_mae: 2.2766
# Epoch 69/125
# 26/26 [==============================] - 0s 898us/step - loss: 5.6624 - mae: 1.7625 - val_loss: 9.1783 - val_mae: 2.2592
# Epoch 70/125
# 26/26 [==============================] - 0s 934us/step - loss: 8.3173 - mae: 1.8964 - val_loss: 9.7715 - val_mae: 2.3491
# Epoch 71/125
# 26/26 [==============================] - 0s 932us/step - loss: 6.4271 - mae: 1.7383 - val_loss: 8.5008 - val_mae: 2.1673
# Epoch 72/125
# 26/26 [==============================] - 0s 915us/step - loss: 6.6863 - mae: 1.8241 - val_loss: 8.2926 - val_mae: 2.1417
# Epoch 73/125
# 26/26 [==============================] - 0s 903us/step - loss: 5.5806 - mae: 1.7239 - val_loss: 9.0075 - val_mae: 2.2208
# Epoch 74/125
# 26/26 [==============================] - 0s 917us/step - loss: 6.5653 - mae: 1.7834 - val_loss: 9.7025 - val_mae: 2.3691
# Epoch 75/125
# 26/26 [==============================] - 0s 915us/step - loss: 7.7265 - mae: 1.8327 - val_loss: 12.9180 - val_mae: 2.7014
# Epoch 76/125
# 26/26 [==============================] - 0s 938us/step - loss: 5.1341 - mae: 1.6728 - val_loss: 11.0849 - val_mae: 2.4307
# Epoch 77/125
# 26/26 [==============================] - 0s 956us/step - loss: 6.2142 - mae: 1.8389 - val_loss: 9.8223 - val_mae: 2.3039
# Epoch 78/125
# 26/26 [==============================] - 0s 1ms/step - loss: 5.5783 - mae: 1.6957 - val_loss: 9.8984 - val_mae: 2.3705
# Epoch 79/125
# 26/26 [==============================] - 0s 1ms/step - loss: 5.2845 - mae: 1.6485 - val_loss: 9.8800 - val_mae: 2.3287
# Epoch 80/125
# 26/26 [==============================] - 0s 969us/step - loss: 6.3356 - mae: 1.7645 - val_loss: 8.3785 - val_mae: 2.1213
# Epoch 81/125
# 26/26 [==============================] - 0s 955us/step - loss: 5.1794 - mae: 1.6930 - val_loss: 10.3969 - val_mae: 2.4205
# Epoch 82/125
# 26/26 [==============================] - 0s 927us/step - loss: 5.0441 - mae: 1.6585 - val_loss: 11.0765 - val_mae: 2.4434
# Epoch 83/125
# 26/26 [==============================] - 0s 946us/step - loss: 5.1386 - mae: 1.6213 - val_loss: 8.9109 - val_mae: 2.2037
# Epoch 84/125
# 26/26 [==============================] - 0s 982us/step - loss: 6.0518 - mae: 1.7131 - val_loss: 8.5954 - val_mae: 2.1606
# Epoch 85/125
# 26/26 [==============================] - 0s 991us/step - loss: 5.1869 - mae: 1.6508 - val_loss: 8.5205 - val_mae: 2.1528
# Epoch 86/125
# 26/26 [==============================] - 0s 976us/step - loss: 5.4142 - mae: 1.6202 - val_loss: 11.4997 - val_mae: 2.5667
# Epoch 87/125
# 26/26 [==============================] - 0s 1ms/step - loss: 6.2798 - mae: 1.7885 - val_loss: 8.8560 - val_mae: 2.1862
# Epoch 88/125
# 26/26 [==============================] - 0s 1ms/step - loss: 5.7911 - mae: 1.5934 - val_loss: 8.7617 - val_mae: 2.1768
# Epoch 89/125
# 26/26 [==============================] - 0s 949us/step - loss: 4.9161 - mae: 1.6350 - val_loss: 11.0772 - val_mae: 2.4548
# Epoch 90/125
# 26/26 [==============================] - 0s 986us/step - loss: 4.2897 - mae: 1.5015 - val_loss: 9.6924 - val_mae: 2.3023
# Epoch 91/125
# 26/26 [==============================] - 0s 964us/step - loss: 5.8677 - mae: 1.6534 - val_loss: 9.6641 - val_mae: 2.3073
# Epoch 92/125
# 26/26 [==============================] - 0s 956us/step - loss: 5.4725 - mae: 1.6626 - val_loss: 9.1839 - val_mae: 2.2432
# Epoch 93/125
# 26/26 [==============================] - 0s 962us/step - loss: 4.2792 - mae: 1.5728 - val_loss: 11.2627 - val_mae: 2.4854
# Epoch 94/125
# 26/26 [==============================] - 0s 968us/step - loss: 4.6567 - mae: 1.6060 - val_loss: 8.9793 - val_mae: 2.2049
# Epoch 95/125
# 26/26 [==============================] - 0s 960us/step - loss: 4.7158 - mae: 1.5367 - val_loss: 8.9786 - val_mae: 2.1889
# Epoch 96/125
# 26/26 [==============================] - 0s 983us/step - loss: 4.6037 - mae: 1.5426 - val_loss: 10.7374 - val_mae: 2.4036
# Epoch 97/125
# 26/26 [==============================] - 0s 971us/step - loss: 4.8922 - mae: 1.6048 - val_loss: 8.8527 - val_mae: 2.2155
# Epoch 98/125
# 26/26 [==============================] - 0s 951us/step - loss: 4.1494 - mae: 1.4518 - val_loss: 9.9490 - val_mae: 2.3596
# Epoch 99/125
# 26/26 [==============================] - 0s 946us/step - loss: 4.4022 - mae: 1.5028 - val_loss: 8.3206 - val_mae: 2.1257
# Epoch 100/125
# 26/26 [==============================] - 0s 1ms/step - loss: 4.1997 - mae: 1.5103 - val_loss: 11.0996 - val_mae: 2.4914
# Epoch 101/125
# 26/26 [==============================] - 0s 964us/step - loss: 5.2836 - mae: 1.6427 - val_loss: 8.8195 - val_mae: 2.2459
# Epoch 102/125
# 26/26 [==============================] - 0s 965us/step - loss: 5.7641 - mae: 1.5872 - val_loss: 7.8880 - val_mae: 2.1182
# Epoch 103/125
# 26/26 [==============================] - 0s 971us/step - loss: 3.8863 - mae: 1.4324 - val_loss: 8.8487 - val_mae: 2.2079
# Epoch 104/125
# 26/26 [==============================] - 0s 970us/step - loss: 4.0333 - mae: 1.4377 - val_loss: 9.9392 - val_mae: 2.3364
# Epoch 105/125
# 26/26 [==============================] - 0s 973us/step - loss: 4.1486 - mae: 1.4719 - val_loss: 8.7853 - val_mae: 2.2154
# Epoch 106/125
# 26/26 [==============================] - 0s 993us/step - loss: 6.0059 - mae: 1.6682 - val_loss: 9.3217 - val_mae: 2.2308
# Epoch 107/125
# 26/26 [==============================] - 0s 978us/step - loss: 4.2944 - mae: 1.5434 - val_loss: 9.0103 - val_mae: 2.2411
# Epoch 108/125
# 26/26 [==============================] - 0s 959us/step - loss: 5.1705 - mae: 1.5910 - val_loss: 9.9216 - val_mae: 2.3997
# Epoch 109/125
# 26/26 [==============================] - 0s 1ms/step - loss: 4.7619 - mae: 1.5502 - val_loss: 8.8320 - val_mae: 2.1464
# Epoch 110/125
# 26/26 [==============================] - 0s 1ms/step - loss: 3.9017 - mae: 1.4728 - val_loss: 12.6530 - val_mae: 2.6945
# Epoch 111/125
# 26/26 [==============================] - 0s 996us/step - loss: 4.2630 - mae: 1.5145 - val_loss: 8.7665 - val_mae: 2.2014
# Epoch 112/125
# 26/26 [==============================] - 0s 970us/step - loss: 4.3354 - mae: 1.5419 - val_loss: 9.8822 - val_mae: 2.3175
# Epoch 113/125
# 26/26 [==============================] - 0s 976us/step - loss: 3.5420 - mae: 1.4160 - val_loss: 12.8965 - val_mae: 2.6979
# Epoch 114/125
# 26/26 [==============================] - 0s 929us/step - loss: 4.8168 - mae: 1.5739 - val_loss: 8.8470 - val_mae: 2.2068
# Epoch 115/125
# 26/26 [==============================] - 0s 922us/step - loss: 4.3741 - mae: 1.4679 - val_loss: 8.8080 - val_mae: 2.1991
# Epoch 116/125
# 26/26 [==============================] - 0s 917us/step - loss: 3.7900 - mae: 1.4498 - val_loss: 11.0717 - val_mae: 2.4681
# Epoch 117/125
# 26/26 [==============================] - 0s 909us/step - loss: 4.0524 - mae: 1.4556 - val_loss: 8.2045 - val_mae: 2.0783
# Epoch 118/125
# 26/26 [==============================] - 0s 948us/step - loss: 4.4859 - mae: 1.4863 - val_loss: 8.4308 - val_mae: 2.1444
# Epoch 119/125
# 26/26 [==============================] - 0s 920us/step - loss: 3.5661 - mae: 1.3473 - val_loss: 9.6259 - val_mae: 2.3154
# Epoch 120/125
# 26/26 [==============================] - 0s 914us/step - loss: 3.8049 - mae: 1.3844 - val_loss: 8.7752 - val_mae: 2.1941
# Epoch 121/125
# 26/26 [==============================] - 0s 915us/step - loss: 3.4738 - mae: 1.3590 - val_loss: 9.7107 - val_mae: 2.3271
# Epoch 122/125
# 26/26 [==============================] - 0s 908us/step - loss: 4.2177 - mae: 1.5109 - val_loss: 9.6545 - val_mae: 2.2818
# Epoch 123/125
# 26/26 [==============================] - 0s 910us/step - loss: 3.2908 - mae: 1.3371 - val_loss: 9.1322 - val_mae: 2.2210
# Epoch 124/125
# 26/26 [==============================] - 0s 905us/step - loss: 3.4073 - mae: 1.3878 - val_loss: 8.2630 - val_mae: 2.0845
# Epoch 125/125
# 26/26 [==============================] - 0s 905us/step - loss: 3.7378 - mae: 1.3971 - val_loss: 8.1316 - val_mae: 2.0787

# %%
test_mse_score, test_mae_score = model.evaluate(X_test, y_test, verbose=0)

# %%
test_mae_score
# Out:
# 2.078742504119873
